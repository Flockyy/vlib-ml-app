# %%
from pycaret.regression import *
data = pd.read_csv('train_df.csv')
test = pd.read_csv('test_df.csv')

# %%
numerical_columns = ['weather', 'temp', 'atemp','humidity', 'windspeed']
categorical_columns = ['season','holiday', 'workingday']

# %%
s = setup(data, test_data=test, target='count', categorical_features = categorical_columns, numeric_features=numerical_columns)
# Out:
# <style type="text/css">
# #T_0733d_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0733d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0733d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0733d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0733d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0733d_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_0733d_row0_col1" class="data row0 col1" >334</td>
#     </tr>
#     <tr>
#       <th id="T_0733d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0733d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0733d_row1_col1" class="data row1 col1" >count</td>
#     </tr>
#     <tr>
#       <th id="T_0733d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_c4d73 th {
#   text-align: left;
# }
# ...

# %%
print(best)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#               random_state=334, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
save_model(best, 'best_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=['season', 'holiday',
#                                                              'workingday'],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=['Unnamed: 0'],
#                                        ml_usecase='regression',
#                                        numerical_features=['weather', 'temp',
#                                                            'atemp', 'humidity',
#                                                            'windspeed'],
#                                        target='count', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy...
#                   LGBMRegressor(boosting_type='gbdt', class_weight=None,
# ...
