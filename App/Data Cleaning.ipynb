# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
df = pd.read_csv('train.csv')

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df['date'] = [df['datetime']]
df['year'] = df['datetime'].dt.year
df['month'] = df['datetime'].dt.month
df['day'] = df['datetime'].dt.day
df['hour'] = df['datetime'].dt.hour

# %%
df
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count  date  year  \
# 0      14.395        81     0.0000       3          13     16     0  2011
# 1      13.635        80     0.0000       8          32     40     0  2011
# 2      13.635        80     0.0000       5          27     32     0  2011
# 3      14.395        75     0.0000       3          10     13     0  2011
# 4      14.395        75     0.0000       0           1      1     0  2011
# ...       ...       ...        ...     ...         ...    ...   ...   ...
# 10881  19.695        50    26.0027       7         329    336    18  2012
# 10882  17.425        57    15.0013      10         231    241    18  2012
# 10883  15.910        61    15.0013       4         164    168    18  2012
# 10884  17.425        61     6.0032      12         117    129    18  2012
# 10885  16.665        66     8.9981       4          84     88    18  2012
#
#        month  day  hour
# 0          1    1     0
# 1          1    1     1
# 2          1    1     2
# 3          1    1     3
# 4          1    1     4
# ...      ...  ...   ...
# 10881     12   19    19
# 10882     12   19    20
# 10883     12   19    21
# 10884     12   19    22
# 10885     12   19    23
#
# [10886 rows x 17 columns]
