# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
y_train = train['count']
X_train = train.drop(['count', 'atemp'], axis=1)
y_test = test['count']
X_test = test.drop(['count', 'atemp'], axis=1)

# %%
X_train = np.log1p(X_train)
X_test = np.log1p(X_test)

# %%
X_train
# Out:
#         season  holiday  workingday   weather      temp  humidity  windspeed  \
# 0     0.693147      0.0         0.0  0.693147  2.383243  4.406719   0.000000
# 1     0.693147      0.0         0.0  0.693147  2.304583  4.394449   0.000000
# 2     0.693147      0.0         0.0  0.693147  2.304583  4.394449   0.000000
# 3     0.693147      0.0         0.0  0.693147  2.383243  4.330733   0.000000
# 4     0.693147      0.0         0.0  0.693147  2.383243  4.330733   0.000000
# ...        ...      ...         ...       ...       ...       ...        ...
# 9058  1.386294      0.0         0.0  1.098612  3.304686  4.304065   2.302395
# 9059  1.386294      0.0         0.0  1.098612  3.304686  4.304065   2.638914
# 9060  1.386294      0.0         0.0  1.386294  3.274121  4.369448   1.946367
# 9061  1.386294      0.0         0.0  1.098612  3.274121  4.369448   2.485023
# 9062  1.386294      0.0         0.0  1.098612  3.274121  4.304065   0.000000
#
# ...

# %%
from lightgbm import LGBMRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_squared_log_error

# %%
lgb = LGBMRegressor(learning_rate=0.05, n_estimators=100, num_leaves=1000, max_depth=-1, min_child_samples=60)

# %%
lgb.fit(X_train, y_train)
pred = lgb.predict(X_test)

train_score = lgb.score(X_train, y_train)
r2 = r2_score(y_test, pred)
mae = mean_absolute_error(y_test, pred)
mse = mean_squared_error(y_test, pred, squared=True)
rmse = mean_squared_error(y_test, pred, squared=False)

print(f'Train r2 score: ', train_score, '\n'
      'Test: ', '\n'
      ' - r2 score: ',  r2, '\n'
      ' - mae: ',  mae, '\n'
      ' - mse: ',  mse, '\n'
      ' - rmse: ',  rmse, '\n'
      )
# Out:
# Train r2 score:  0.961355751126974
# Test:
#  - r2 score:  0.9065036332252565
#  - mae:  45.20635950432297
#  - mse:  4342.308098611537
#  - rmse:  65.8961918369456
