# %% [markdown]
# #### Data import

# %%
import pandas as pd

train_df = pd.read_csv('../data/cleaned_train.csv')
test_df = pd.read_csv('../data/cleaned_test.csv')

# %% [markdown]
# #### Pycaret setup
#
# - Remove outliers
# - Ignore low variance features
# - Power feature to make data more gaussian like
# - Normalize data
# - Select best feature by importance for the model
# - Log experiment on features

# %%
from pycaret.regression import *
s = setup(train_df, test_data = test_df, remove_outliers=True, ignore_low_variance=True, transformation=True, normalize=True, feature_selection=True, log_experiment = True, target = 'count')
# Out:
# <style type="text/css">
# #T_14fcd_row17_col1, #T_14fcd_row27_col1, #T_14fcd_row29_col1, #T_14fcd_row34_col1, #T_14fcd_row38_col1, #T_14fcd_row42_col1, #T_14fcd_row50_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_14fcd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14fcd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_14fcd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14fcd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14fcd_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_14fcd_row0_col1" class="data row0 col1" >1970</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_14fcd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_14fcd_row1_col1" class="data row1 col1" >count</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_14fcd_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_14fcd_row2_col1" class="data row2 col1" >(8607, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_14fcd_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_14fcd_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_14fcd_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_14fcd_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_14fcd_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_14fcd_row5_col1" class="data row5 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_14fcd_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_14fcd_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_14fcd_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_14fcd_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_14fcd_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_14fcd_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_14fcd_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_14fcd_row9_col1" class="data row9 col1" >(8176, 46)</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_14fcd_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_14fcd_row10_col1" class="data row10 col1" >(2279, 46)</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_14fcd_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_14fcd_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_14fcd_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_14fcd_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_14fcd_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_14fcd_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_14fcd_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_14fcd_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_14fcd_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_14fcd_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_14fcd_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_14fcd_row16_col1" class="data row16 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_14fcd_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_14fcd_row17_col1" class="data row17 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_14fcd_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_14fcd_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_14fcd_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_14fcd_row19_col1" class="data row19 col1" >47d0</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_14fcd_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_14fcd_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_14fcd_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_14fcd_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_14fcd_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_14fcd_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_14fcd_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_14fcd_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_14fcd_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_14fcd_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_14fcd_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_14fcd_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_14fcd_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_14fcd_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_14fcd_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_14fcd_row27_col1" class="data row27 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_14fcd_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_14fcd_row28_col1" class="data row28 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_14fcd_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_14fcd_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_14fcd_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_14fcd_row30

# %% [markdown]
# #### Model comparison

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_e3487 th {
#   text-align: left;
# }
# #T_e3487_row0_col0, #T_e3487_row0_col5, #T_e3487_row0_col6, #T_e3487_row1_col0, #T_e3487_row1_col1, #T_e3487_row1_col2, #T_e3487_row1_col3, #T_e3487_row1_col4, #T_e3487_row1_col5, #T_e3487_row1_col6, #T_e3487_row2_col0, #T_e3487_row2_col1, #T_e3487_row2_col2, #T_e3487_row2_col3, #T_e3487_row2_col4, #T_e3487_row3_col0, #T_e3487_row3_col1, #T_e3487_row3_col2, #T_e3487_row3_col3, #T_e3487_row3_col4, #T_e3487_row3_col5, #T_e3487_row3_col6, #T_e3487_row4_col0, #T_e3487_row4_col1, #T_e3487_row4_col2, #T_e3487_row4_col3, #T_e3487_row4_col4, #T_e3487_row4_col5, #T_e3487_row4_col6, #T_e3487_row5_col0, #T_e3487_row5_col1, #T_e3487_row5_col2, #T_e3487_row5_col3, #T_e3487_row5_col4, #T_e3487_row5_col5, #T_e3487_row5_col6, #T_e3487_row6_col0, #T_e3487_row6_col1, #T_e3487_row6_col2, #T_e3487_row6_col3, #T_e3487_row6_col4, #T_e3487_row6_col5, #T_e3487_row6_col6, #T_e3487_row7_col0, #T_e3487_row7_col1, #T_e3487_row7_col2, #T_e3487_row7_col3,
level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_e3487_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_e3487_row1_col1" class="data row1 col1" >35.0417</td>
#       <td id="T_e3487_row1_col2" class="data row1 col2" >3117.4985</td>
#       <td id="T_e3487_row1_col3" class="data row1 col3" >51.9022</td>
#       <td id="T_e3487_row1_col4" class="data row1 col4" >0.8615</td>
#       <td id="T_e3487_row1_col5" class="data row1 col5" >0.5171</td>
#       <td id="T_e3487_row1_col6" class="data row1 col6" >0.5471</td>
#       <td id="T_e3487_row1_col7" class="data row1 col7" >0.5950</td>
#     </tr>
#     <tr>
#       <th id="T_e3487_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_e3487_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_e3487_row2_col1" class="data row2 col1" >33.2972</td>
#       <td id="T_e3487_row2_col2" class="data row2 col2" >2978.9198</td>
#       <td id="T_e3487_row2_col3" class="data row2 col3" >51.4218</td>
#       <td id="T_e3487_row2_col4" class="data row2 col4" >0.8550</td>
#       <td id="T_e3487_row2_col5" class="data row2 col5" >0.3906</td>
#       <td id="T_e3487_row2_col6" class="data row2 col6" >0.4013</td>
#       <td id="T_e3487_row2_col7" class="data row2 col7" >0.9600</td>
#     </tr>
#     <tr>
#       <th id="T_e3487_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_e3487_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_e3487_row3_col1" class="data row3 col1" >34.1742</td>
#       <td id="T_e3487_row3_col2" class="data row3 col2" >3181.7927</td>
#       <td id="T_e3487_row3_col3" class="data row3 col3" >53.3152</td>
#       <td id="T_e3487_row3_col4" class="data row3 col4" >0.8362</td>
#       <td id="T_e3487_row3_col5" class="data row3 col5" >0.4162</td>
#       <td id="T_e3487_row3_col6" class="data row3 col6" >0.4460</td>
#       <td id="T_e3487_row3_col7" class="data row3 col7" >0.9690</td>
#     </tr>
#     <tr>
#       <th id="T_e3487_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_e3487_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_e3487_row4_col1" class="data row4 col1" >45.9657</td>
#       <td id="T_e3487_row4_col2" class="data row4 col2" >4540.9911</td>
#       <td id="T_e3487_row4_col3" class="data row4 col3" >63.6019</td>
#       <td id="T_e3487_row4_col4" class="data row4 col4" >0.7910</td>
#       <td id="T_e3487_row4_col5" class="data row4 col5" >0.6616</td>
#       <td id="T_e3487_row4_col6" class="data row4 col6" >0.9503</td>
#       <td id="T_e3487_row4_col7" class="data row4 col7" >0.3200</td>
#     </tr>
#     <tr>
#       <th id="T_e3487_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_e3487_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_e3487_row5_col1" class="data row5 col1" >42.4719</td>
#       <td id="T_e3487_row5_col2" class="data row5 col2" >4874.3324</td>
#       <td id="T_e3487_row5_col3" class="data row5 col3" >66.3246</td>
#       <td id="T_e3487_row5_col4" class="data row5 col4" >0.7580</td>
#       <td id="T_e3487_row5_col5" class="data ro

# %% [markdown]
# #### Model evaluation

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# #### Model saving

# %%
save_model(best, 'lgbm_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='count',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy='...
#                   LGBMRegressor(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
#                                 learning_rate=0.1, max_depth=-1,
#                                 min_child_samples=20, min_child_weight=0.001,
#                                 min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                 num_leaves=31, objective=None, random_state=1970,
#                                 reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#                                 subsample=1.0, subsample_for_bin=200000,
#                                 subsample_freq=0)]],
#           verbose=False),
#  'lgbm_pipeline.pkl')

# %% [markdown]
# #### Just a test with a pre-tuned model by picaret but, not used

# %%
tuned_model = tune_model(best)
# Out:
# <style type="text/css">
# #T_2d5d7_row10_col0, #T_2d5d7_row10_col1, #T_2d5d7_row10_col2, #T_2d5d7_row10_col3, #T_2d5d7_row10_col4, #T_2d5d7_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_2d5d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d5d7_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_2d5d7_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_2d5d7_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_2d5d7_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_2d5d7_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_2d5d7_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d5d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2d5d7_row0_col0" class="data row0 col0" >19.8276</td>
#       <td id="T_2d5d7_row0_col1" class="data row0 col1" >691.6503</td>
#       <td id="T_2d5d7_row0_col2" class="data row0 col2" >26.2992</td>
#       <td id="T_2d5d7_row0_col3" class="data row0 col3" >0.7806</td>
#       <td id="T_2d5d7_row0_col4" class="data row0 col4" >0.6045</td>
#       <td id="T_2d5d7_row0_col5" class="data row0 col5" >1.0684</td>
#     </tr>
#     <tr>
#       <th id="T_2d5d7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2d5d7_row1_col0" class="data row1 col0" >26.4013</td>
#       <td id="T_2d5d7_row1_col1" class="data row1 col1" >1288.1834</td>
#       <td id="T_2d5d7_row1_col2" class="data row1 col2" >35.8913</td>
#       <td id="T_2d5d7_row1_col3" class="data row1 col3" >0.8341</td>
#       <td id="T_2d5d7_row1_col4" class="data row1 col4" >0.6120</td>
#       <td id="T_2d5d7_row1_col5" class="data row1 col5" >0.9890</td>
#     </tr>
#     <tr>
#       <th id="T_2d5d7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2d5d7_row2_col0" class="data row2 col0" >32.1288</td>
#       <td id="T_2d5d7_row2_col1" class="data row2 col1" >2004.7607</td>
#       <td id="T_2d5d7_row2_col2" class="data row2 col2" >44.7746</td>
#       <td id="T_2d5d7_row2_col3" class="data row2 col3" >0.9050</td>
#       <td id="T_2d5d7_row2_col4" class="data row2 col4" >0.5194</td>
#       <td id="T_2d5d7_row2_col5" class="data row2 col5" >0.5600</td>
#     </tr>
#     <tr>
#       <th id="T_2d5d7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2d5d7_row3_col0" class="data row3 col0" >30.6126</td>
#       <td id="T_2d5d7_row3_col1" class="data row3 col1" >1788.6304</td>
#       <td id="T_2d5d7_row3_col2" class="data row3 col2" >42.2922</td>
#       <td id="T_2d5d7_row3_col3" class="data row3 col3" >0.9230</td>
#       <td id="T_2d5d7_row3_col4" class="data row3 col4" >0.4374</td>
#       <td id="T_2d5d7_row3_col5" class="data row3 col5" >0.4294</td>
#     </tr>
#     <tr>
#       <th id="T_2d5d7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2d5d7_row4_col0" class="data row4 col0" >31.2661</td>
#       <td id="T_2d5d7_row4_col1" class="data row4 col1" >1865.0016</td>
#       <td id="T_2d5d7_row4_col2" class="data row4 col2" >43.1857</td>
#       <td id="T_2d5d7_row4_col3" class="data row4 col3" >0.9169</td>
#       <td id="T_2d5d7_row4_col4" class="data row4 col4" >0.4576</td>
#       <td id="T_2d5d7_row4_col5" class="data row4 col5" >0.4408</td>
#     </tr>
#     <tr>
#       <th id="T_2d5d7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2d5d7_row5_col0" class="data row5 col0" >29.7350</td>
#       <td id="T_2d5d7_row5_col1" class="data row5 col1" >1722.2407</td>
#       <td id="T_2d5d7_row5_col2" class="data row5 col2" >41.4999</td>
#       <td id="T_2d5d7_row5_col3" class="data row5 col3" >0.9021</td>
#       <td id="T_2d5d7_row5_col4" class="data row5 col4" >0.5718</td>
#       <td id="T_2d5d7_row5_col5" class="data row5 col5" >0.7652</td>
#     </tr>
#     <tr>
#       <th id="T_2d5d7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2d5d7_row6_col0" class="data row6 col0" >26.9223</td>
#       <td id="T_2d5d7_row6_col1" class="data row6 col1" >1546.9043</td>
#       <td id="T_2d5d7_row6_col2" class="data row6 col2" >39.3307</td>
#       <td id="T_2d5d7_row6_col3" class="data row6 col3" >0.8936</td>
#       <td id="T_2d5d7_row6_col4" class="data row6 col4" >0.5451</td>
#       <td id="T_2d5d7_row6_col5" class="data row6 col5" >0.6821</td>
#     </tr>
#     <tr>
#       <th id="T_2d5d7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2d5d7_row7_col0" class="data row7 col0" >49.2284</td>
#       <td id="T_2d5d7_row7_col1" class="data row7 col1" >5790.7151</td>
#       <td id="T_2d5d7_row7_col2" class="data row7 col2" >76.0967</td>
#       <td id="T_2d5d7_row7_col3" class="data row7 col3" >0.8317</td>
#       <td id="T_2d5d7_row7_col4" class="data row7 col4" >0.5378</td>
#       <td id="T_2d5d7_row7_col5" class="data row7 col5" >0.6986</td>
#     </tr>
#     <tr>
#       <th id="T_2d5d7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2d5d7_row8_col0" class="data row8 col0" >53.5653</td>
#       <td id="T_2d5d7_row8_col1" class="data row8 col1" >6009.5002</td>
#       <td id="T_2d5d7_row8_col2" class="data row8 col2" >77.5210</td>
#       <td id="T_2d5d7_row8_col3" class="data row8 col3" >0.8716</td>
#       <td id="T_2d5d7_row8_col4" class="data row8 col4" >0.5923</td>
#       <td id="T_2d5d7_row8_col5" class="data row8 col5" >0.7373</td>
#     </tr>
#     <tr>
#       <th id="T_2d5d7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2d5d7_row9_col0" class="data row9 col0" >69.2522</td>
#       <td id="T_2d5d7_row9_col1" class="data row9 col1" >8065.4575</td>
#       <td id="T_2d5d7_row9_col2" class="data row9 col2" >89.8079</td>
#       <td id="T_2d5d7_row9_col3" class="data row9 col3" >0.8296</td>
#       <td id="T_2d5d7_row9_col4" class="data row9 col4" >0.6684</td>
#       <td id="T_2d5d7_row9_col5" class="data row9 col5" >0.8883</td>
#     </tr>
#     <tr>
#       <th id="T_2d5d7_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_2d5d7_row10_col0" class="data row10 col0" >36.8940</td>
#       <td id="T_2d5d7_row10_col1" class="data row10 col1" >3077.3044</td>
#       <td id="T_2d5d7_row10_col2" class="data row10 col2" >51.6699</td>
#       <td id="T_2d5d7_row10_col3" class="data row10 col3" >0.8688</td>
#       <td id="T_2d5d7_row10_col4" class="data row10 col4" >0.5546</td>
#       <td id="T_2d5d7_row10_col5" class="data row10 col5" >0.7259</td>
#     </tr>
#     <tr>
#       <th id="T_2d5d7_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_2d5d7_row11_col0" class="data row11 col0" >14.5705</td>
#       <td id="T_2d5d7_row11_col1" class="data row11 col1" >2412.3302</td>
#       <td id="T_2d5d7_row11_col2" class="data row11 col2" >20.1872</td>
#       <td id="T_2d5d7_row11_col3" class="data row11 col3" >0.0449</td>
#       <td id="T_2d5d7_row11_col4" class="data row11 col4" >0.0672</td>
#       <td id="T_2d5d7_row11_col5" class="data row11 col5" >0.2035</td>
#     </tr>
#   </tbody>
# </table>

# %%
save_model(tuned_model, 'tuned_lgbm_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='count',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy='...
#                                 colsample_bytree=1.0, feature_fraction=0.4,
#                                 importance_type='split', learning_rate=0.05,
#                                 max_depth=-1, min_child_samples=16,
#                                 min_child_weight=0.001, min_split_gain=0.6,
#                                 n_estimators=300, n_jobs=-1, num_leaves=70,
#                                 objective=None, random_state=1970,
#                                 reg_alpha=0.05, reg_lambda=0.5, silent='warn',
#                                 subsample=1.0, subsample_for_bin=200000,
#                                 subsample_freq=0)]],
#           verbose=False),
#  'tuned_lgbm_pipeline.pkl')

# %% [markdown]
# ##### Best models seems to be XGBoost and LightGBM so generally Gradient boosting methods, i'll try those two by myself
